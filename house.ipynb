# %% [markdown]
# #Importing Required Modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # import the house.csv File In "df" Variable

# %%
df=pd.read_csv("/content/house.csv")

# %% [markdown]
# #checking the data

# %%
df
# Out:
#     price_lac  area_sqft  bhk  bathrooms  balconies  floors furnishing_type  \
# 0        20.0      560.0    1        2.0          1       6     Unfurnished
# 1        20.0      600.0    1        1.0          1       4     Unfurnished
# 2        20.0      600.0    1        1.0          1       4     Unfurnished
# 3        12.0      605.0    2        2.0          1       4  Semi furnished
# 4        15.0      605.0    2        2.0          1       4  Semi furnished
# ..        ...        ...  ...        ...        ...     ...             ...
# 89       59.0     4573.0    2        2.0          0       1     Unfurnished
# 90      150.0     5227.0    5        5.0          0       3  Semi furnished
# 91      150.0     6500.0    3        2.0          2       1  Semi furnished
# 92       58.0     6534.0    3        2.0          0       1     Unfurnished
# 93      150.0     8720.0    2        2.0          0       1     Unfurnished
#
#         location      property_type
# ...

# %% [markdown]
# # Name of the Columns present in dataset

# %%
df.columns
# Out:
# Index(['price_lac', 'area_sqft', 'bhk', 'bathrooms', 'balconies', 'floors',
#        'furnishing_type', 'location', 'property_type'],
#       dtype='object')

# %% [markdown]
# # description about the numerical data like mean median mode

# %%
df.describe()
# Out:
#         price_lac    area_sqft        bhk  bathrooms  balconies     floors
# count   94.000000    92.000000  94.000000  91.000000  94.000000  94.000000
# mean    56.486277  1908.065217   2.446809   2.252747   1.127660   3.882979
# std     38.841617  1483.359528   0.862816   0.810945   0.870472   2.816451
# min     12.000000   560.000000   1.000000   1.000000   0.000000   1.000000
# 25%     31.000000  1000.000000   2.000000   2.000000   0.000000   2.000000
# 50%     48.000000  1450.000000   2.000000   2.000000   1.000000   3.000000
# 75%     63.000000  2405.000000   3.000000   2.500000   2.000000   5.000000
# max    180.000000  8720.000000   5.000000   5.000000   3.000000  12.000000

# %% [markdown]
# #ploting the scatterplot to verify the relation between [price and area of sqrt]

# %%
plt.figure(figsize=(10,10))
sns.set_style("darkgrid")
sns.scatterplot(x="price_lac",y="area_sqft",data=df,hue="property_type")

# %% [markdown]
# #Finding the correlations

# %%
df.corr()
# Out:
#            price_lac  area_sqft       bhk  bathrooms  balconies    floors
# price_lac   1.000000   0.683125  0.727532   0.649643   0.182072 -0.182101
# area_sqft   0.683125   1.000000  0.416005   0.288648  -0.063044 -0.343415
# bhk         0.727532   0.416005  1.000000   0.826512   0.223889 -0.195069
# bathrooms   0.649643   0.288648  0.826512   1.000000   0.337989 -0.050770
# balconies   0.182072  -0.063044  0.223889   0.337989   1.000000  0.484224
# floors     -0.182101  -0.343415 -0.195069  -0.050770   0.484224  1.000000

# %% [markdown]
# #ploting the correlation using heatmap

# %%
sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# #verify the correlation between bhk and price

# %%
sns.lineplot(x="bhk",y="price_lac",data=df)

# %% [markdown]
# #checking for outliers

# %%
sns.boxplot(df.price_lac)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.isnull().sum()
# Out:
# price_lac          0
# area_sqft          2
# bhk                0
# bathrooms          3
# balconies          0
# floors             0
# furnishing_type    2
# location           0
# property_type      0
# dtype: int64

# %% [markdown]
# #cleaning the data using dropna()

# %%
df.dropna(axis=0,inplace=True)

# %% [markdown]
# #visualising the distribution of  price data

# %%
sns.distplot(df["price_lac"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #plotting the distribution of area_sqrt using kde

# %%
sns.kdeplot(df.area_sqft,shade=True,log_scale=False)

# %% [markdown]
# #checking the count of property_type

# %%
sns.histplot(df.property_type,color="red")

# %%
df.dtypes
# Out:
# price_lac          float64
# area_sqft          float64
# bhk                  int64
# bathrooms          float64
# balconies            int64
# floors               int64
# furnishing_type     object
# location            object
# property_type       object
# dtype: object

# %% [markdown]
# # count of furnishing_type

# %%
sns.histplot(df["furnishing_type"])

# %% [markdown]
# #plotting scatter plot to find the relationship

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(y="price_lac",x="bhk",hue="location",size="area_sqft",data=df)

# %%
df[["price_lac","bhk"]].corr()
# Out:
#            price_lac       bhk
# price_lac   1.000000  0.723766
# bhk         0.723766  1.000000

# %% [markdown]
# # checking the correlation between the prices

# %%
sns.lineplot(x="bathrooms",y="price_lac",data=df)

# %% [markdown]
# #kde visualization

# %%
plt.figure(figsize=(10,10
))
sns.kdeplot(df["bathrooms"],hue=df["property_type"],shade=True)

# %% [markdown]
# #distplot to find the more data distribution of area_sqrt is about 1000 to 2500 sqrt

# %%
sns.distplot(df["area_sqft"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
